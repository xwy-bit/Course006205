# %%
# %matplotlib inline
from scipy.io import wavfile 
import matplotlib.pyplot as plt

# %%
fs, data = wavfile.read('1.wav') # 音频数据导入
audioData = [(ele/2**8.)*2-1 for ele in data]

# %%
plt.plot(audioData,'g')
plt.show()
